# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y = [i for i in range(20,100,3)]
x = [i for i in range(len(y))]
plt.scatter(x,y)
plt.show()
# shift Enter to draw the graph

# %%
def create_random_list(length):
    some_list = range(length)
    random.shuffle(some_list)
    return some_list

def display(some_list):
    plt.clf()
    plt.bar(range)
    
import random
random.random()
# Out:
# 0.2328732150859968

# %%
pts=[]
total = 50000

for i in range(total):
    x = random.random()*2-1
    y = random.random()*2-1
    pts.append((x,y))
    

unit_circle=plt.Circle((0,0), 1.0, color='g', fill=False)
plt.figure(figsize=(10,10));
plt.axis([-1,1, -1,1]);
fig = plt.gcf()
fig.gca().add_artist(unit_circle)
t = zip(*pts) # pts [(x0,y0), (x1,y1), ..., ]
plt.scatter(t[0], t[1], marker='.', alpha=0.3)

print 4.0 * len(filter((lambda pt: pt[0]*pt[0] + pt[1]*pt[1] < 1), pts)) / total
total
# Out:
# 3.13984
# 50000
